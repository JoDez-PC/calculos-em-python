# %%
print('TABOADA DE NÚMEROS INTEIROS')

x = int(input('Qual o a tabuada que você deseja saber?'))

print('RESULTADOS')

for i in range(10):
  conta = i*x
  print('{}x{}={}'.format(x, i, conta))
# Out:
# TABOADA DE NÚMEROS INTEIROS
# Qual o a tabuada que você deseja saber?5
# RESULTADOS
# 5x0=0
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
