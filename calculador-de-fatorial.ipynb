# %%
numero = int(input('De qual número você deseja saber o fatorial?'))
fatorial = numero
contador = 1

while (numero-contador)>1:
  fatorial = fatorial*(numero-contador)
  contador += 1
print('{}! = {}' .format(numero, fatorial))
# Out:
# De qual número você deseja saber o fatorial?3
# 3! = 6
